# %% [markdown]
# # Data Viking Class
#
# ## Data Analysis

# %%
import pandas as pd

# %%
data = pd.read_csv("dataset/credit_risk.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  age     sex  job housing saving_accounts checking_account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    credit_amount  duration              purpose  risk reference  income  \
# 0           1169         6             radio/TV  good   2023-01     NaN
# 1           5951        48             radio/TV   bad   2023-02     NaN
# 2           2096        12            education  good   2023-03     NaN
# 3           7882        42  furniture/equipment  good   2023-04     NaN
# 4           4870        24                  car   bad   2023-01     NaN
#
#               cpf  score_serasa
# 0  410.927.380-37           102
# ...
